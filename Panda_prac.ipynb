# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.1.4'

# %%
pd.show_versions()
# Out:
# C:\Users\pranj\anaconda3\Lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# INSTALLED VERSIONS
# ------------------
# commit              : a671b5a8bf5dd13fb19f0e88edc679bc9e15c673
# python              : 3.11.7.final.0
# python-bits         : 64
# OS                  : Windows
# OS-release          : 10
# Version             : 10.0.22631
# machine             : AMD64
# processor           : Intel64 Family 6 Model 154 Stepping 3, GenuineIntel
# byteorder           : little
# LC_ALL              : None
# LANG                : None
# LOCALE              : English_India.1252
#
# pandas              : 2.1.4
# numpy               : 1.26.4
# pytz                : 2023.3.post1
# dateutil            : 2.8.2
# setuptools          : 68.2.2
# pip                 : 23.3.1
# Cython              : None
# pytest              : 7.4.0
# hypothesis          : None
# sphinx              : 5.0.2
# ...

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df=pd.DataFrame(data,index=labels)

# %%
##Summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %%
df.head(3)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %%
df[['animal','age']]
#To select  multiple columns at a time we use double dimensions
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %%
df[['animal','age']].iloc[[2,4,8]]
#To iterate particular rows
# Out:
#   animal  age
# c  snake  0.5
# e    dog  5.0
# i    dog  7.0

# %%
print(df[df.visits>=3])
print(df[df.age==None])
# Out:
#   animal  age  visits priority
# b    cat  3.0       3      yes
# d    dog  NaN       3      yes
# f    cat  2.0       3       no
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %%
df[df.age.isna()]
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %%
df[(df.animal=="cat")&(df.age<3)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %%
df[df.animal=="cat"].loc[df.visits==3].loc[df.priority=="no"]
#To locate for given two or more conditions
# Out:
#   animal  age  visits priority
# f    cat  2.0       3       no

# %%
#To update on using a condition
df.loc[df['age']==2,'age']=7

# %%
#To update on using indexes
df.loc['f','age']=2

# %%
df['visits'].sum()
# Out:
# 19

# %%
df['age'].mean()
# Out:
# 3.4375

# %%
#Grouping and finding mean for each member
df.groupby('animal')['age'].mean()
# Out:
# animal
# cat      2.5
# dog      5.0
# snake    2.5
# Name: age, dtype: float64

# %%
prac_df=pd.DataFrame(df)
prac_df['priority'].replace("no","never",inplace=True)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2    never
# d    dog  NaN       3      yes
# e    dog  5.0       2    never
# f    cat  2.0       3    never
# g  snake  4.5       1    never
# h    cat  NaN       1      yes
# i    dog  7.0       2    never
# j    dog  3.0       1    never

# %%
prac_df.loc[df.age>3,'age']=10.0

# %%
#prac_df.dropna()
prac_df['priority'].replace("never","no",inplace=True)

# %%
prac_df
# Out:
#   animal   age  visits priority
# a    cat   2.5       1      yes
# b    cat   3.0       3      yes
# c  snake   0.5       2       no
# d    dog   NaN       3      yes
# e    dog  10.0       2       no
# f    cat   2.0       3       no
# g  snake  10.0       1       no
# h    cat   NaN       1      yes
# i    dog  10.0       2       no
# j    dog   3.0       1       no

# %%
new_row={
    'animal':'snake',
    'age':5.0,
    'visits':3,
    'priority':'no'
}
#To add row
prac_df=pd.concat([prac_df,pd.DataFrame([new_row])])

# %%
#To delete row
prac_df.drop(prac_df.index[-1])
# Out:
#   animal   age  visits priority
# a    cat   2.5       1      yes
# b    cat   3.0       3      yes
# c  snake   0.5       2       no
# d    dog   NaN       3      yes
# e    dog  10.0       2       no
# f    cat   2.0       3       no
# g  snake  10.0       1       no
# h    cat   NaN       1      yes
# i    dog  10.0       2       no
# j    dog   3.0       1       no

# %%
#To add row using loc
prac_df.loc['k']=['snake',4.5,3,"no"]
prac_df
# Out:
#   animal   age  visits priority
# a    cat   2.5       1      yes
# b    cat   3.0       3      yes
# c  snake   0.5       2       no
# d    dog   NaN       3      yes
# e    dog  10.0       2       no
# f    cat   2.0       3       no
# g  snake  10.0       1       no
# h    cat   NaN       1      yes
# i    dog  10.0       2       no
# j    dog   3.0       1       no
# 0  snake   5.0       3       no
# k  snake   4.5       3       no

# %%
prac_df.drop(prac_df.index[-1])
# Out:
#   animal   age  visits priority
# a    cat   2.5       1      yes
# b    cat   3.0       3      yes
# c  snake   0.5       2       no
# d    dog   NaN       3      yes
# e    dog  10.0       2       no
# f    cat   2.0       3       no
# g  snake  10.0       1       no
# h    cat   NaN       1      yes
# i    dog  10.0       2       no
# j    dog   3.0       1       no
# 0  snake   5.0       3       no

# %%
#inplace is very important to delete the data in actual 
prac_df.drop(prac_df.index[-1],inplace=True)
prac_df
# Out:
#   animal   age  visits priority
# a    cat   2.5       1      yes
# b    cat   3.0       3      yes
# c  snake   0.5       2       no
# d    dog   NaN       3      yes
# e    dog  10.0       2       no
# f    cat   2.0       3       no
# g  snake  10.0       1       no
# h    cat   NaN       1      yes
# i    dog  10.0       2       no
# j    dog   3.0       1       no

# %%
prac_df.groupby('animal')['animal'].count()
# Out:
# animal
# cat      4
# dog      4
# snake    2
# Name: animal, dtype: int64

# %%
prac_df['animal'].value_counts()
# Out:
# animal
# cat      4
# dog      4
# snake    2
# Name: count, dtype: int64

# %%
df[df['age'].between(2,4)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %%
df.sort_values(by='age',ascending=False)
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# b    cat  3.0       3      yes
# j    dog  3.0       1       no
# a    cat  2.5       1      yes
# f    cat  2.0       3       no
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %%
df.sort_values(by=['visits','age'],ascending=[False,True])
#Note also we can set a list in by to sort according to multiple columns
# Out:
#   animal  age  visits priority
# f    cat  2.0       3       no
# b    cat  3.0       3      yes
# d    dog  NaN       3      yes
# c  snake  0.5       2       no
# e    dog  5.0       2       no
# i    dog  7.0       2       no
# a    cat  2.5       1      yes
# j    dog  3.0       1       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes

# %%
df.loc[df["age"].isna(),"age"]=1.0
#to replace isna() with default values

# %%
prac_df.loc[prac_df["age"].isna(),"age"]=df['age'].mean()

# %%
prac_df
# Out:
#   animal     age  visits priority
# a    cat     2.5       1      yes
# b    cat     3.0       3      yes
# c  snake     0.5       2       no
# d    dog  3.4375       3      yes
# e    dog    10.0       2       no
# f    cat     2.0       3       no
# g  snake    10.0       1       no
# h    cat  3.4375       1      yes
# i    dog    10.0       2       no
# j    dog     3.0       1       no

# %%
#Pivot tables
new_df=df.pivot_table(values=['age'],index=['animal'],columns=['visits'],aggfunc='mean')

# %%
new_df
# Out:
#         age
# visits    1    2    3
# animal
# cat     2.5  NaN  2.5
# dog     3.0  6.0  NaN
# snake   4.5  0.5  NaN
